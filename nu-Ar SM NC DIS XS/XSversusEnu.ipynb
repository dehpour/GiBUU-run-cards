# %%
import matplotlib.pyplot as plt

# %%
# Input these from GiBUU 2023 by run card.job for each Enu and then integrate dsigma over 0<=x<=1 and 0<=y<=1/(1+M_N x/(2 E_nu)) via XYintegratedXS.ipynb

Enu = 5
sigma = 0.5595645872999998*1e-38

# %%
plt.figure(figsize=(8, 6))

plt.scatter((Enu),(sigma), label='GiBUU 2023')

#plt.xscale('log')
#plt.yscale('log')

plt.title(r'$\nu_{\mu}-^{40}_{18}\ {\rm Ar}$ SM NC DIS X.S.')
plt.xlabel(r'$E_{\nu}\ [{\rm GeV}]$')
plt.ylabel(r'$\sigma$ per nucleon $[{\rm cm}^2$]')
plt.legend()
plt.show()
